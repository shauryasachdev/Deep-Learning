# %% [markdown]
# <a href="https://colab.research.google.com/github/shauryasachdev/Deep-Learning/blob/main/Convolutional_Neural_Networks_Keras_Recap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy==2.0.2
# !pip install pandas==2.2.2
# !pip install tensorflow_cpu==2.19.0
# !pip install matplotlib==3.9.2
# Out:
# Requirement already satisfied: numpy==2.0.2 in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: pandas==2.2.2 in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas==2.2.2) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas==2.2.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas==2.2.2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas==2.2.2) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas==2.2.2) (1.17.0)
# Requirement already satisfied: tensorflow_cpu==2.19.0 in /usr/local/lib/python3.12/dist-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow_cpu==2.19.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow_cpu==2.19.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow_cpu==2.19.0) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow_cpu==2.19.0) (0.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow_cpu==2.19.0) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow_cpu==2.19.0) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow_cpu==2.19.0) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow_cpu==2.19.0) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow_cpu==2.19.0) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow_cpu==2.19.0) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow_cpu==2.19.0) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow_cpu==2.19.0) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow_cpu==2.19.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow_cpu==2.19.0) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow_cpu==2.19.0) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow_cpu==2.19.0) (1.76.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow_cpu==2.19.0) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow_cpu==2.19.0) (3.10.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow_cpu==2.19.0) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow_cpu==2.19.0) (3.15.1)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow_cpu==2.19.0) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow_cpu==2.19.0) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow_cpu==2.19.0) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow_cpu==2.19.0) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow_cpu==2.19.0) (0.18.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow_cpu==2.19.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow_cpu==2.19.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow_cpu==2.19.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow_cpu==2.19.0) (2026.1.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow_cpu==2.19.0) (3.10)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow_cpu==2.19.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow_cpu==2.19.0) (3.1.5)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow_cpu==2.19.0) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow_cpu==2.19.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow_cpu==2.19.0) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow_cpu==2.19.0) (0.1.2)
# Requirement already satisfied: matplotlib==3.9.2 in /usr/local/lib/python3.12/dist-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.2) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.2) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.2) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.2) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.2) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.2) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.2) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.2) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib==3.9.2) (1.17.0)

# %%
import os
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Input
from keras.utils import to_categorical

from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten

import matplotlib.pyplot as plt

# %%
from keras.datasets import mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train.shape
# Out:
# (60000, 28, 28)

# %%
y_train.shape
# Out:
# (60000,)

# %%
X_test.shape
# Out:
# (10000, 28, 28)

# %%
y_test.shape
# Out:
# (10000,)

# %%
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1).astype('float32')

# %%
X_train = X_train/255
X_test = X_test/255

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

num_classes = y_test.shape[1]

print(num_classes)
# Out:
# 10

# %%
y_train.shape
# Out:
# (60000, 10)

# %%
def convolutional_model():

  model = Sequential()
  model.add(Input(shape=(28,28,1)))
  model.add(Conv2D(16, (5,5), strides=(1,1), activation ='relu'))
  model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

  model.add(Flatten())
  model.add(Dense(100, activation='relu'))
  model.add(Dense(num_classes, activation = 'softmax'))

  model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
  return model

# %%
model = convolutional_model()

model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200, verbose=2)

scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# Epoch 1/10
# 300/300 - 31s - 103ms/step - accuracy: 0.9181 - loss: 0.2899 - val_accuracy: 0.9707 - val_loss: 0.0956
# Epoch 2/10
# 300/300 - 20s - 67ms/step - accuracy: 0.9763 - loss: 0.0815 - val_accuracy: 0.9835 - val_loss: 0.0554
# Epoch 3/10
# 300/300 - 22s - 72ms/step - accuracy: 0.9833 - loss: 0.0562 - val_accuracy: 0.9847 - val_loss: 0.0510
# Epoch 4/10
# 300/300 - 41s - 136ms/step - accuracy: 0.9871 - loss: 0.0426 - val_accuracy: 0.9861 - val_loss: 0.0419
# Epoch 5/10
# 300/300 - 41s - 137ms/step - accuracy: 0.9895 - loss: 0.0341 - val_accuracy: 0.9878 - val_loss: 0.0372
# Epoch 6/10
# 300/300 - 41s - 136ms/step - accuracy: 0.9914 - loss: 0.0282 - val_accuracy: 0.9860 - val_loss: 0.0417
# Epoch 7/10
# 300/300 - 22s - 72ms/step - accuracy: 0.9926 - loss: 0.0239 - val_accuracy: 0.9841 - val_loss: 0.0465
# Epoch 8/10
# 300/300 - 41s - 136ms/step - accuracy: 0.9941 - loss: 0.0197 - val_accuracy: 0.9876 - val_loss: 0.0375
# Epoch 9/10
# 300/300 - 21s - 69ms/step - accuracy: 0.9954 - loss: 0.0157 - val_accuracy: 0.9871 - val_loss: 0.0368
# Epoch 10/10
# 300/300 - 20s - 68ms/step - accuracy: 0.9964 - loss: 0.0126 - val_accuracy: 0.9867 - val_loss: 0.0399
# Accuracy: 0.9866999983787537
#  Error: 1.3300001621246338

# %%
model = convolutional_model()

# fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=1024, verbose=2)

# evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# Epoch 1/10
# 59/59 - 24s - 412ms/step - accuracy: 0.8202 - loss: 0.6906 - val_accuracy: 0.9303 - val_loss: 0.2444
# Epoch 2/10
# 59/59 - 41s - 689ms/step - accuracy: 0.9436 - loss: 0.1922 - val_accuracy: 0.9617 - val_loss: 0.1349
# Epoch 3/10
# 59/59 - 21s - 357ms/step - accuracy: 0.9653 - loss: 0.1207 - val_accuracy: 0.9722 - val_loss: 0.0939
# Epoch 4/10
# 59/59 - 21s - 363ms/step - accuracy: 0.9752 - loss: 0.0875 - val_accuracy: 0.9771 - val_loss: 0.0756
# Epoch 5/10
# 59/59 - 41s - 691ms/step - accuracy: 0.9800 - loss: 0.0713 - val_accuracy: 0.9798 - val_loss: 0.0629
# Epoch 6/10
# 59/59 - 40s - 684ms/step - accuracy: 0.9827 - loss: 0.0604 - val_accuracy: 0.9820 - val_loss: 0.0558
# Epoch 7/10
# 59/59 - 22s - 369ms/step - accuracy: 0.9856 - loss: 0.0528 - val_accuracy: 0.9823 - val_loss: 0.0505
# Epoch 8/10
# 59/59 - 21s - 363ms/step - accuracy: 0.9871 - loss: 0.0462 - val_accuracy: 0.9837 - val_loss: 0.0500
# Epoch 9/10
# 59/59 - 41s - 696ms/step - accuracy: 0.9881 - loss: 0.0426 - val_accuracy: 0.9836 - val_loss: 0.0488
# Epoch 10/10
# 59/59 - 40s - 677ms/step - accuracy: 0.9887 - loss: 0.0392 - val_accuracy: 0.9846 - val_loss: 0.0475
# Accuracy: 0.9846000075340271
#  Error: 1.53999924659729

# %%
model = convolutional_model()

# fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=25, batch_size=1024, verbose=2)

# evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# Epoch 1/25
# 59/59 - 25s - 429ms/step - accuracy: 0.8229 - loss: 0.6664 - val_accuracy: 0.9282 - val_loss: 0.2501
# Epoch 2/25
# 59/59 - 21s - 363ms/step - accuracy: 0.9392 - loss: 0.2116 - val_accuracy: 0.9555 - val_loss: 0.1559
# Epoch 3/25
# 59/59 - 22s - 373ms/step - accuracy: 0.9607 - loss: 0.1372 - val_accuracy: 0.9679 - val_loss: 0.1107
# Epoch 4/25
# 59/59 - 41s - 702ms/step - accuracy: 0.9715 - loss: 0.0996 - val_accuracy: 0.9763 - val_loss: 0.0830
# Epoch 5/25
# 59/59 - 21s - 357ms/step - accuracy: 0.9776 - loss: 0.0790 - val_accuracy: 0.9787 - val_loss: 0.0711
# Epoch 6/25
# 59/59 - 21s - 352ms/step - accuracy: 0.9811 - loss: 0.0671 - val_accuracy: 0.9817 - val_loss: 0.0610
# Epoch 7/25
# 59/59 - 21s - 362ms/step - accuracy: 0.9824 - loss: 0.0591 - val_accuracy: 0.9829 - val_loss: 0.0545
# Epoch 8/25
# 59/59 - 21s - 353ms/step - accuracy: 0.9854 - loss: 0.0514 - val_accuracy: 0.9824 - val_loss: 0.0524
# Epoch 9/25
# 59/59 - 42s - 705ms/step - accuracy: 0.9863 - loss: 0.0461 - val_accuracy: 0.9827 - val_loss: 0.0517
# Epoch 10/25
# 59/59 - 21s - 348ms/step - accuracy: 0.9878 - loss: 0.0424 - val_accuracy: 0.9849 - val_loss: 0.0464
# Epoch 11/25
# 59/59 - 42s - 717ms/step - accuracy: 0.9887 - loss: 0.0392 - val_accuracy: 0.9817 - val_loss: 0.0515
# Epoch 12/25
# 59/59 - 39s - 667ms/step - accuracy: 0.9891 - loss: 0.0366 - val_accuracy: 0.9840 - val_loss: 0.0518
# Epoch 13/25
# 59/59 - 22s - 367ms/step - accuracy: 0.9907 - loss: 0.0329 - val_accuracy: 0.9858 - val_loss: 0.0452
# Epoch 14/25
# 59/59 - 41s - 695ms/step - accuracy: 0.9914 - loss: 0.0300 - val_accuracy: 0.9863 - val_loss: 0.0393
# Epoch 15/25
# 59/59 - 22s - 374ms/step - accuracy: 0.9920 - loss: 0.0278 - val_accuracy: 0.9869 - val_loss: 0.0422
# Epoch 16/25
# 59/59 - 40s - 685ms/step - accuracy: 0.9926 - loss: 0.0265 - val_accuracy: 0.9862 - val_loss: 0.0396
# Epoch 17/25
# 59/59 - 21s - 358ms/step - accuracy: 0.9935 - loss: 0.0232 - val_accuracy: 0.9863 - val_loss: 0.0388
# Epoch 18/25
# 59/59 - 41s - 692ms/step - accuracy: 0.9941 - loss: 0.0222 - val_accuracy: 0.9872 - val_loss: 0.0411
# Epoch 19/25
# 59/59 - 40s - 676ms/step - accuracy: 0.9940 - loss: 0.0212 - val_accuracy: 0.9867 - val_loss: 0.0381
# Epoch 20/25
# 59/59 - 22s - 371ms/step - accuracy: 0.9947 - loss: 0.0184 - val_accuracy: 0.9878 - val_loss: 0.0372
# Epoch 21/25
# 59/59 - 21s - 348ms/step - accuracy: 0.9953 - loss: 0.0174 - val_accuracy: 0.9877 - val_loss: 0.0383
# Epoch 22/25
# 59/59 - 42s - 706ms/step - accuracy: 0.9957 - loss: 0.0163 - val_accuracy: 0.9879 - val_loss: 0.0377
# Epoch 23/25
# 59/59 - 21s - 359ms/step - accuracy: 0.9959 - loss: 0.0150 - val_accuracy: 0.9883 - val_loss: 0.0377
# Epoch 24/25
# 59/59 - 21s - 355ms/step - accuracy: 0.9966 - loss: 0.0136 - val_accuracy: 0.9865 - val_loss: 0.0403
# Epoch 25/25
# 59/59 - 41s - 692ms/step - accuracy: 0.9969 - loss: 0.0128 - val_accuracy: 0.9875 - val_loss: 0.0397
# Accuracy: 0.987500011920929
#  Error: 1.2499988079071045
